# %% [markdown]
# ## Download data from Gdrive

# %%
import gdown

url="https://drive.google.com/file/d/15_tLbn8WEEX4nq4-eZoh7_EgzJXBgHBQ/view?usp=sharing"

# %%
file_id=url.split("/")[-2]
file_id
# Out:
# '15_tLbn8WEEX4nq4-eZoh7_EgzJXBgHBQ'

# %%
#this is a prefix download link for google drive till the file id
prefix='https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id,"kidney-ct-scan-image.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=15_tLbn8WEEX4nq4-eZoh7_EgzJXBgHBQ
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=15_tLbn8WEEX4nq4-eZoh7_EgzJXBgHBQ&confirm=t&uuid=75b28643-bd4a-444d-bfe0-ccfaa2abe95d
# To: c:\Users\farha\Kidney-Disease-Classification-MLflow-DVC\research\kidney-ct-scan-image.zip
# 100%|██████████| 940M/940M [02:07<00:00, 7.37MB/s]
# 'kidney-ct-scan-image.zip'
